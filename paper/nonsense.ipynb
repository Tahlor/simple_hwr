# %%
# %reload_ext autoreload
# %autoreload 2

import matplotlib
# %matplotlib inline

print(matplotlib.get_backend())

import sys
sys.path.append("..")
sys.path.append("../synthesis")
sys.path.append("../loss_module")



from gen_preds_online import load_online_dataloader
from hwr_utils.stroke_dataset import BasicDataset, StrokeRecoveryDataset
import calculate_nn
from calculate_nn import plot
# Out:
# module://ipykernel.pylab.backend_inline

# %%
test_dataloader_resample, test_dataset_resample = load_online_dataloader(batch_size=1, shuffle=False, resample=True)
#test_dataloader, test_dataset = load_online_dataloader(batch_size=1, shuffle=False, resample=False)

plot(test_dataset_resample[0]['gt'],test_dataset_resample[0]['raw_gt'], name="suck5")
# x = test_dataset_resample[0]
# plot(x['gt'], x['raw_gt'], name="suck5")
# Out:
# INFO:root.hwr_utils.stroke_dataset:Loading data traditional way ['/media/data/GitHub/simple_hwr/data/online_coordinate_data/MAX_stroke_vlargeTrnSetFull/test_online_coords.json']
# /media/data/GitHub/simple_hwr/data/online_coordinate_data/MAX_stroke_vlargeTrnSetFull/test_online_coords.json
# Loading .npy version
# INFO:root.hwr_utils.stroke_dataset:('Dataloader size', 501)
# INFO:root.hwr_utils.stroke_dataset:('Dataloader size', 501)
# Loading JSON:  /media/data/GitHub/simple_hwr/data/prepare_online_data/online_augmentation.json
# HW dataloader size 10927
# # of items in dataset: 501 items without GT text:  0
# MAX 350.0 323
# DOPE!!!
# MAX 350.0 323
# MAX 350.0 323
# DOPE!!!
# MAX 350.0 323

# %%
test_dataloader_resample, test_dataset_resample = load_online_dataloader(batch_size=1, shuffle=False, resample=True)
test_dataloader, test_dataset = load_online_dataloader(batch_size=1, shuffle=False, resample=False)
	
plot(test_dataset_resample[0]['gt'],test_dataset_resample[0]['raw_gt'], name="suck5")
# Out:
# INFO:root.hwr_utils.stroke_dataset:Loading data traditional way ['/media/data/GitHub/simple_hwr/data/online_coordinate_data/MAX_stroke_vlargeTrnSetFull/test_online_coords.json']
# INFO:root.hwr_utils.stroke_dataset:('Dataloader size', 501)
# /media/data/GitHub/simple_hwr/data/online_coordinate_data/MAX_stroke_vlargeTrnSetFull/test_online_coords.json
# Loading .npy version
# INFO:root.hwr_utils.stroke_dataset:('Dataloader size', 501)
# INFO:root.hwr_utils.stroke_dataset:Loading data traditional way ['/media/data/GitHub/simple_hwr/data/online_coordinate_data/MAX_stroke_vlargeTrnSetFull/test_online_coords.json']
# Loading JSON:  /media/data/GitHub/simple_hwr/data/prepare_online_data/online_augmentation.json
# HW dataloader size 10927
# # of items in dataset: 501 items without GT text:  0
# /media/data/GitHub/simple_hwr/data/online_coordinate_data/MAX_stroke_vlargeTrnSetFull/test_online_coords.json
# Loading .npy version
# INFO:root.hwr_utils.stroke_dataset:('Dataloader size', 501)
# ...

# %%
plot(test_dataset_resample[0]['gt'],test_dataset_resample[0]['raw_gt'], name="suck5")
# Out:
# DOPE!!!
# DOPE!!!

# %%
test_dataloader_resample, test_dataset_resample = load_online_dataloader(batch_size=1, shuffle=False, resample=True)
plot(test_dataset_resample[0]["raw_gt"], test_dataset_resample[0]["gt"], name="suck11")
# Out:
# INFO:root.hwr_utils.stroke_dataset:Loading data traditional way ['/media/data/GitHub/simple_hwr/data/online_coordinate_data/MAX_stroke_vlargeTrnSetFull/test_online_coords.json']
# /media/data/GitHub/simple_hwr/data/online_coordinate_data/MAX_stroke_vlargeTrnSetFull/test_online_coords.json
# Loading .npy version
# INFO:root.hwr_utils.stroke_dataset:('Dataloader size', 501)
# INFO:root.hwr_utils.stroke_dataset:('Dataloader size', 501)
# Loading JSON:  /media/data/GitHub/simple_hwr/data/prepare_online_data/online_augmentation.json
# HW dataloader size 10927
# # of items in dataset: 501 items without GT text:  0
# DOPE!!!
# DOPE!!!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-bbf35e2cc7d9> in <module>
#       1 test_dataloader_resample, test_dataset_resample = load_online_dataloader(batch_size=1, shuffle=False, resample=True)
# ...

# %%
plot(test_dataset[0]['gt'],test_dataset[0]['raw_gt'], name="suck5")
# Out:
# HERE
# HERE
